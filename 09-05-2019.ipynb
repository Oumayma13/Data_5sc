# %%
#Charger les biblio
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import numpy as np
import string 
from subprocess import check_output
import seaborn as sns
from pylab import *
# %matplotlib inline
sns.set()

# %%
# Lire la table avec 'header'
df = pd.read_csv('Hmvl2.csv', sep=';', engine='python')

# %%
# Remplacer les NaN par des zeros dans trame_hmvl
df.trame_hmvl.fillna('0', inplace=True)

# %%
# Reindexer la dataframe
df.index = range(len(df))

# %%
#changeaons les noms de colonnes
df.columns = ['code', 'id','equipement_id', 'date','trame']

# %%
df.head()
# Out:
#                    code    id  equipement_id                     date  \
# 0                   MBS  7357           7357  2019-02-18 00:00:00.146
# 1                   MPA  7356           7356  2019-02-18 00:00:00.146
# 2                   MPH  7355           7355  2019-02-18 00:00:00.146
# 3  SFB-TPCCEN_RDTSCB001  7850           7850  2019-02-18 00:00:01.374
# 4  SMA-INTBAU_RDTSCB001  7859           7859  2019-02-18 00:00:01.374
#
#                                                trame
# 0  0543110903705431109037256930750412569307504125...
# 1                                                  @
# 2                 058520920440585209204405852092044@
# 3                                                  @
# 4                                                  @

# %%
# On enlève les @
df["trame"] = df["trame"].str.replace("@", "")

# %%
# On ajoute une colonne Count pour compter chacune
df['Count'] = df['trame'].str.len()

# %%
df.head()
# Out:
#                    code    id  equipement_id                     date  \
# 0                   MBS  7357           7357  2019-02-18 00:00:00.146
# 1                   MPA  7356           7356  2019-02-18 00:00:00.146
# 2                   MPH  7355           7355  2019-02-18 00:00:00.146
# 3  SFB-TPCCEN_RDTSCB001  7850           7850  2019-02-18 00:00:01.374
# 4  SMA-INTBAU_RDTSCB001  7859           7859  2019-02-18 00:00:01.374
#
#                                                trame  Count
# 0  0543110903705431109037256930750412569307504125...     55
# 1                                                         0
# 2                  058520920440585209204405852092044     33
# 3                                                         0
# 4                                                         0

# %%
df.groupby("Count").count().head()
# Out:
#          code      id  equipement_id    date   trame
# Count
# 1       86402   86402          86402   86402   86402
# 5           1       1              1       1       1
# 11     149327  149327         149327  149327  149327
# 12        245     245            245     245     245
# 16          1       1              1       1       1

# %%
df.Count.max()/11
# Out:
# 46.0

# %%
# lignes differentes de zero
df = df[df.Count != 0]

# %%
# lignes differentes de 1
df = df[df.Count != 1]

# %% [markdown]
# Donc il faut créer 46 nouveaux champs qui contient les 11 caractères pour chaque véhicules.

# %%
# Supprimons la colonne
df = df.drop(['Count'], axis=1)

# %%
##### UNE LISTE A MINIMISER #######
liste = ["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x31','x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45']
#,'x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45'

# %%
# séparer les caractères de la colonne trame 
for i in range(len(liste)):
    df[liste[i]] = df["trame"].str.slice(11*i,11*(i+1))

# %%
# Créer 14 tables vides
##### UNE LISTE A MINIMISER #######
#l = ['df0','df1','df2','df3','df4','df5','df6','df7','df8','df9','df10','df11','df12', 'df13',
     #'df14','df15','df16', 'df17','df18','df19','df20', 'df23','df21','df22', 'df24'
    #,'df25','df26','df27', 'df28','df29','df31','df32', 'df33','df30','df34'
    #,'df35','df36','df37', 'df38','df39','df40','df41', 'df42','df43','df44','df45']
l2 = range(46)
np.str(l2)
for c in l:
    c =  'dff'+ c
    exec('{} = pd.DataFrame()'.format(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\ANACONDA\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\ANACONDA\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\ANACONDA\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...

# %%
dff45
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-31b0564f2128> in <module>
# ----> 1 dff45
#
# NameError: name 'dff45' is not defined

# %%
# Supprimer les colonnes xj

# df0 = df[['x0','date','id','code']]
df0 = df.drop(["x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
# df1
df1 = df.drop(["x0","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14','x15',
               'x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df2 = df.drop(["x0","x1","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45' ,'trame'], axis=1)
df3 = df.drop(["x0","x1","x2","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45','trame'], axis=1)

df4 = df.drop(["x0","x1","x2","x3","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df5 = df.drop(["x0","x1","x2","x3","x4","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45','trame'], axis=1)

df6 = df.drop(["x0","x1","x2","x3","x4","x5","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df7 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45','trame'], axis=1)

# %%
df8 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df9 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df10 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df11 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df12 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df13 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df14 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df15 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df16 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df17 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df18 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df19 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df20 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

# %%
df21 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df22 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df23 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df24 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df25 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df26 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df27 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df28 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df29 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df30 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

# %%
df31 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df32 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df33 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df34 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df35 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df36 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df37 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x38','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df38 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x39','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df39 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x40', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df40 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39', 'x41', 'x42', 'x43', 'x44','x45', 'trame'], axis=1)
df41 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x12', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40',  'x42', 'x43', 'x44','x45', 'trame'], axis=1)

df42 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11', 'x13', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41',  'x43', 'x44','x45', 'trame'], axis=1)

df43 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x14'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42',  'x44','x45', 'trame'], axis=1)
df44 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13'
        ,'x15','x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x45', 'trame'], axis=1)

df45 = df.drop(["x0","x1","x2","x3","x4","x5","x6","x7","x8","x9",'x10','x11','x12', 'x13', 'x14'
        ,'x16','x17','x18','x19','x20', 'x21', 'x22','x23','x24','x25','x26','x27','x28','x29','x30'
        ,'x32','x33','x34','x35','x36','x37','x38','x39','x40', 'x41', 'x42', 'x43', 'x44', 'trame'], axis=1)

# %%
##### CODE A MINIMISER #######
l = [df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12, df13,
     df14,df15,df16, df17,df18,df19,df20,df21,df22,df23
    , df24 ,df25,df26,df27, df28,df29,df30,df31,df32]
#, df33,df34,df35,df36,df37,df38,df39,df40,df41, df42,df43,df44,df45
    # Séparer la colonne xi en 4 colonnes  
for i, f in zip(range( len(liste)), l):
    f["voie"] = f[liste[i]].str.slice(0,1)
    f["horodatage"] = f[liste[i]].str.slice(1,5)
    f["vitesse"] = f[liste[i]].str.slice(5,8)
    f["longueur"] = f[liste[i]].str.slice(8,11)

# %%
df1
# Out:
#                          code     id  equipement_id                     date  \
# 0                         MBS   7357           7357  2019-02-18 00:00:00.146
# 1                         MPA   7356           7356  2019-02-18 00:00:00.146
# 2                         MPH   7355           7355  2019-02-18 00:00:00.146
# 3        SFB-TPCCEN_RDTSCB001   7850           7850  2019-02-18 00:00:01.374
# 4        SMA-INTBAU_RDTSCB001   7859           7859  2019-02-18 00:00:01.374
# 5        TMA-INTN01_RDTSCB002   7860           7860  2019-02-18 00:00:01.374
# 6                         M1b   6383           6383  2019-02-18 00:00:02.069
# 7                         M1c   6384           6384  2019-02-18 00:00:02.069
# 8                         M1d   6385           6385  2019-02-18 00:00:02.069
# 9                         M1e   6386           6386  2019-02-18 00:00:02.069
# 10                        M3b   6335           6335  2019-02-18 00:00:02.069
# ...
